# %% [markdown]
# # Predicting the price of a flat given a list of predictors using Airbnb dataset.

# %% [markdown]
# # Data Dictionary

# %% [markdown]
# - **calculated_host_listings_count** - continious value which is actual number of host listings - another metric to measure host experience or to distinguish buisness from individual
# - **review_scores_accuracy** - discrete value - numbers between 2 and 10
# - **review_scores_cleanliness** - discrete value - numbers between 2 and 10
# - **review_scores_checkin** - discrete value - numbers between 2 and 10
# - **review_scores_communication** - discrete value - numbers between 2 and 10
# - **review_scores_location** - discrete value - numbers between 2 and 10
# - **review_scores_value** - discrete value - numbers between 2 and 10
# - **instant_bookable** - categorical value - t or false
# - **cancellation_policy** - ordinal value with 5 categories that can be ordered from lowest to highest level of flexibility

# %%
import os
import gmaps
import pandas as pd
import numpy as np
from sklearn import metrics
import matplotlib.pyplot as plt
import seaborn as sns; sns.set(style="whitegrid", color_codes=True)
from dotenv import load_dotenv
from pandas_profiling import ProfileReport
from math import radians, cos, sin, asin, sqrt
from pandarallel import pandarallel

pandarallel.initialize(progress_bar=True)
import locale
locale.setlocale(locale.LC_ALL, 'en_US.UTF-8');
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm
# INFO: Pandarallel will run on 4 workers.
# INFO: Pandarallel will use standard multiprocessing data transfer (pipe) to transfer data between the main process and workers.

# %%
data  = pd.read_csv('../data/interest-features.csv', sep=';')
data.shape
# Out:
# (50796, 51)

# %%
pd.set_option("display.max_columns",300)

# %%
data.sample(5)
# Out:
#        host_response_time host_response_rate host_acceptance_rate  \
# 11827                   0                  0                    0
# 50028  within a few hours                98%                  97%
# 42040      within an hour               100%                  67%
# 31649      within an hour               100%                 100%
# 7434                    0                  0                    0
#
#       host_is_superhost  host_total_listings_count host_has_profile_pic  \
# 11827                 f                        1.0                    t
# 50028                 f                       42.0                    t
# 42040                 t                     2345.0                    t
# 31649                 t                        3.0                    t
# 7434                  f                        1.0                    t
#
#       host_identity_verified neighbourhood_cleansed  \
# 11827                      f       Ditmars Steinway
# 50028                      t         Hell's Kitchen
# 42040                      t     Financial District
# 31649                      t     Bedford-Stuyvesant
# 7434                       t           Clinton Hill
#
#       neighbourhood_group_cleansed smart_location is_location_exact  \
# 11827                       Queens     Queens, NY                 t
# 50028                    Manhattan   New York, NY                 t
# 42040                    Manhattan   New York, NY                 t
# 31649                     Brooklyn   Brooklyn, NY                 t
# 7434                      Brooklyn   Brooklyn, NY                 t
#
#             property_type        room_type  accommodates  bathrooms  bedrooms  \
# 11827           Apartment  Entire home/apt             5        1.0       2.0
# 50028                Loft  Entire home/apt             4        1.0       0.0
# 42040  Serviced apartment  Entire home/apt             2        1.0       0.0
# 31649           Apartment     Private room             2        1.0       1.0
# 7434            Apartment  Entire home/apt             2        1.5       1.0
#
#        beds  bed_type                                          amenities  \
# 11827   2.0  Real Bed  {TV,"Cable TV",Internet,Wifi,"Air conditioning...
# 50028   0.0  Real Bed  {TV,"Cable TV",Internet,Wifi,"Air conditioning...
# 42040   0.0  Real Bed  {TV,"Cable TV",Internet,Wifi,"Air conditioning...
# 31649   1.0  Real Bed  {TV,Wifi,"Air conditioning",Kitchen,Heating,Wa...
# 7434    1.0  Real Bed  {TV,"Cable TV",Internet,Wifi,"Air conditioning...
#
#        price  security_deposit cleaning_fee  guests_included extra_people  \
# 11827  250.0               0.0            0                1        $0.00
# 50028  180.0            1000.0      $150.00                1        $0.00
# 42040  179.0             500.0      $300.00                1        $0.00
# 31649   72.0             500.0       $40.00                1       $25.00
# 7434   145.0               0.0            0                1        $0.00
#
#        minimum_nights  maximum_nights has_availability calendar_last_scraped  \
# 11827               1            1125                t            2020-03-14
# 50028              30             365                t            2020-03-14
# 42040              30            1125                t            2020-03-14
# 31649               6              60                t            2020-03-14
# 7434                2            1125                t            2020-03-14
#
#        number_of_reviews  number_of_reviews_ltm  review_scores_rating  \
# 11827                  0                      0                   NaN
# 50028                  0                      0                   NaN
# 42040                  0                      0                   NaN
# 31649                 13                     11                  98.0
# 7434                   2                      0                  90.0
#
#        review_scores_accuracy  review_scores_cleanliness  \
# 11827                9.613552                   9.284211
# 50028                9.613552                   9.284211
# 42040                9.613552                   9.284211
# 31649               10.000000                  10.000000
# 7434                 9.000000                  10.000000
#
#        review_scores_checkin  review_scores_communication  \
# 11827               9.734848                     9.740066
# 50028               9.734848                     9.740066
# 42040               9.734848                     9.740066
# 31649              10.000000                    10.000000
# 7434               10.000000                    10.000000
#
#        review_scores_location  review_scores_value requires_license  \
# 11827                9.599812             9.386351                f
# 50028                9.599812             9.386351                f
# 42040                9.599812             9.386351                f
# 31649               10.000000            10.000000                f
# 7434                10.000000             8.000000                f
#
#       instant_bookable is_business_travel_ready cancellation_policy  \
# 11827                f                        f            flexible
# 50028                t                        f            flexible
# 42040                f                        f              strict
# 31649                t                        f            moderate
# 7434                 f                        f            moderate
#
#       require_guest_profile_picture require_guest_phone_verification  \
# 11827                             f                                f
# 50028                             t                                f
# 42040                             f                                f
# 31649                             f                                f
# 7434                              f                                f
#
#        calculated_host_listings_count  \
# 11827                               1
# 50028                              42
# 42040                             103
# 31649                               3
# 7434                                1
#
#        calculated_host_listings_count_entire_homes  \
# 11827                                            1
# 50028                                           42
# 42040                                          103
# 31649                                            0
# 7434                                             1
#
#        calculated_host_listings_count_private_rooms  \
# 11827                                             0
# 50028                                             0
# 42040                                             0
# 31649                                             3
# 7434                                              0
#
#        calculated_host_listings_count_shared_rooms  reviews_per_month  \
# 11827                                            0           1.282087
# 50028                                            0           1.282087
# 42040                                            0           1.282087
# 31649                                            0           0.800000
# 7434                                             0           0.040000
#
#        first_review_days  last_review_days  host_since_days
# 11827                0.0               0.0           1594.0
# 50028                0.0               0.0           2935.0
# 42040                0.0               0.0           1635.0
# 31649              525.0             107.0           1309.0
# 7434              1375.0            1353.0           1940.0

# %%
data['host_response_time'].value_counts()
# Out:
# within an hour        20445
# 0                     19006
# within a few hours     6009
# within a day           4218
# a few days or more     1118
# Name: host_response_time, dtype: int64

# %%
df_interest_features = data

# %%
df_interest_features.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50796 entries, 0 to 50795
# Data columns (total 51 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   host_response_time                            50796 non-null  object
#  1   host_response_rate                            50796 non-null  object
#  2   host_acceptance_rate                          50796 non-null  object
#  3   host_is_superhost                             50796 non-null  object
#  4   host_total_listings_count                     50796 non-null  float64
#  5   host_has_profile_pic                          50796 non-null  object
#  6   host_identity_verified                        50796 non-null  object
#  7   neighbourhood_cleansed                        50796 non-null  object
#  8   neighbourhood_group_cleansed                  50796 non-null  object
#  9   smart_location                                50796 non-null  object
#  10  is_location_exact                             50796 non-null  object
#  11  property_type                                 50796 non-null  object
#  12  room_type                                     50796 non-null  object
#  13  accommodates                                  50796 non-null  int64
#  14  bathrooms                                     50796 non-null  float64
#  15  bedrooms                                      50796 non-null  float64
#  16  beds                                          50796 non-null  float64
#  17  bed_type                                      50796 non-null  object
#  18  amenities                                     50796 non-null  object
#  19  price                                         50796 non-null  float64
#  20  security_deposit                              50796 non-null  float64
#  21  cleaning_fee                                  50796 non-null  object
#  22  guests_included                               50796 non-null  int64
#  23  extra_people                                  50796 non-null  object
#  24  minimum_nights                                50796 non-null  int64
#  25  maximum_nights                                50796 non-null  int64
#  26  has_availability                              50796 non-null  object
#  27  calendar_last_scraped                         50796 non-null  object
#  28  number_of_reviews                             50796 non-null  int64
#  29  number_of_reviews_ltm                         50796 non-null  int64
#  30  review_scores_rating                          39365 non-null  float64
#  31  review_scores_accuracy                        50796 non-null  float64
#  32  review_scores_cleanliness                     50796 non-null  float64
#  33  review_scores_checkin                         50796 non-null  float64
#  34  review_scores_communication                   50796 non-null  float64
#  35  review_scores_location                        50796 non-null  float64
#  36  review_scores_value                           50796 non-null  float64
#  37  requires_license                              50796 non-null  object
#  38  instant_bookable                              50796 non-null  object
#  39  is_business_travel_ready                      50796 non-null  object
#  40  cancellation_policy                           50796 non-null  object
#  41  require_guest_profile_picture                 50796 non-null  object
#  42  require_guest_phone_verification              50796 non-null  object
#  43  calculated_host_listings_count                50796 non-null  int64
#  44  calculated_host_listings_count_entire_homes   50796 non-null  int64
#  45  calculated_host_listings_count_private_rooms  50796 non-null  int64
#  46  calculated_host_listings_count_shared_rooms   50796 non-null  int64
#  47  reviews_per_month                             50796 non-null  float64
#  48  first_review_days                             50796 non-null  float64
#  49  last_review_days                              50796 non-null  float64
#  50  host_since_days                               50796 non-null  float64
# dtypes: float64(17), int64(10), object(24)
# memory usage: 19.8+ MB

# %% [markdown]
# ### Encode Boolean Features

# %%
df_interest_features['host_is_superhost'] = df_interest_features['host_is_superhost'].parallel_apply(lambda x: 1 if x=='t' else 0)
df_interest_features['host_has_profile_pic'] = df_interest_features['host_has_profile_pic'].parallel_apply(lambda x: 1 if x=='t' else 0)
df_interest_features['host_identity_verified'] = df_interest_features['host_identity_verified'].parallel_apply(lambda x: 1 if x=='t' else 0)
df_interest_features['require_guest_profile_picture'] = df_interest_features['require_guest_profile_picture'].parallel_apply(lambda x: 1 if x=='t' else 0)
df_interest_features['require_guest_phone_verification'] = df_interest_features['require_guest_phone_verification'].parallel_apply(lambda x: 1 if x=='t' else 0)
df_interest_features['is_location_exact'] = df_interest_features['is_location_exact'].parallel_apply(lambda x: 1 if x=='t' else 0)
df_interest_features['requires_license'] = df_interest_features['requires_license'].parallel_apply(lambda x: 1 if x=='t' else 0)
df_interest_features['instant_bookable'] = df_interest_features['instant_bookable'].parallel_apply(lambda x: 1 if x=='t' else 0)
df_interest_features['is_business_travel_ready'] = df_interest_features['is_business_travel_ready'].parallel_apply(lambda x: 1 if x=='t' else 0)
df_interest_features['has_availability'] = df_interest_features['has_availability'].parallel_apply(lambda x: 1 if x=='t' else 0)
# Out:
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=12699), Label(value='0 / 12699')))…
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=12699), Label(value='0 / 12699')))…
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=12699), Label(value='0 / 12699')))…
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=12699), Label(value='0 / 12699')))…
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=12699), Label(value='0 / 12699')))…
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=12699), Label(value='0 / 12699')))…
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=12699), Label(value='0 / 12699')))…
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=12699), Label(value='0 / 12699')))…
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=12699), Label(value='0 / 12699')))…

# %% [markdown]
# ### Ajusting labels for categorical features

# %%
df_interest_features['host_response_time']= df_interest_features['host_response_time'].replace('0', 'no answer') 
df_interest_features['host_response_time'].value_counts()
# Out:
# within an hour        20445
# no answer             19006
# within a few hours     6009
# within a day           4218
# a few days or more     1118
# Name: host_response_time, dtype: int64

# %% [markdown]
# ### Convert Numbers as String to Number

# %%
df_interest_features['host_response_rate'] = df_interest_features['host_response_rate'].parallel_apply(lambda x: float(x.rstrip("%")))
df_interest_features['host_acceptance_rate'] = df_interest_features['host_acceptance_rate'].parallel_apply(lambda x: float(x.rstrip("%")))
# Out:
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=12699), Label(value='0 / 12699')))…
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=12699), Label(value='0 / 12699')))…

# %% [markdown]
# ### Drop Unuseful Columns

# %%
df_interest_features = df_interest_features.drop(['smart_location'], axis=1)

# %%
df_interest_features['cleaning_fee'] = df_interest_features['cleaning_fee'].parallel_apply(lambda x: re.sub(r'\$', '', x))
df_interest_features['cleaning_fee'] = df_interest_features['cleaning_fee'].parallel_apply(lambda x: float(locale.atof(x)))

df_interest_features['extra_people'] = df_interest_features['extra_people'].parallel_apply(lambda x: re.sub(r'\$', '', x))
df_interest_features['extra_people'] = df_interest_features['extra_people'].parallel_apply(lambda x: float(locale.atof(x)))
# Out:
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=12699), Label(value='0 / 12699')))…
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=12699), Label(value='0 / 12699')))…
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=12699), Label(value='0 / 12699')))…
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=12699), Label(value='0 / 12699')))…

# %%
df_interest_features['review_scores_rating'] = df_interest_features['review_scores_rating'].fillna(0)

# %%
df_interest_features['calendar_last_scraped'] = pd.to_datetime(df_interest_features['calendar_last_scraped'])
df_interest_features['calendar_last_scraped_days'] = (pd.datetime.now() - df_interest_features['calendar_last_scraped']).dt.days
df_interest_features = df_interest_features.drop(['calendar_last_scraped'], axis=1)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:2: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.

# %%
df_interest_features.to_csv('../data/interest-features-2.csv', sep=';', index=False)

# %%
data  = pd.read_csv(r'../data/interest-features-2.csv', sep=';')
data.shape
# Out:
# (50796, 50)

# %%
with_cat_df = data

# %% [markdown]
# ### Ordinal Encoder to response_time_dict

# %%
response_time_dict = {'no answer' : 1,
                      'within an hour': 2,
                      'within a few hours': 3,
                      'within a day': 4,
                      'a few days or more': 5}

with_cat_df['host_response_time_ordinal'] = with_cat_df['host_response_time'].map(response_time_dict)
with_cat_df['host_response_time'] = with_cat_df.drop(['host_response_time'], axis=1)

# %% [markdown]
# ### One Hot Encoding to bed_type

# %%
with_cat_df = pd.get_dummies(with_cat_df, prefix=['bed_type'], columns=['bed_type'])

# %% [markdown]
# ### One Hot Encoding to neighbourhood_group

# %%
with_cat_df = pd.get_dummies(with_cat_df, prefix=['neighbourhood_group'], columns=['neighbourhood_group_cleansed'])
with_cat_df = with_cat_df.drop(['neighbourhood_cleansed'], axis=1)

# %% [markdown]
# ### One Hot Encoding to room_type

# %%
with_cat_df = pd.get_dummies(with_cat_df, prefix=['room_type'], columns=['room_type'])

# %% [markdown]
# ### Ordinal Encoder to cancellation_policy

# %%
response_time_dict = {'flexible' : 1,
                      'moderate': 2,
                      'strict': 3,
                      'strict_14_with_grace_period': 4,
                      'super_strict_30': 5,
                      'super_strict_60': 6}

with_cat_df['cancellation_policy_ordinal'] = with_cat_df['cancellation_policy'].map(response_time_dict)
with_cat_df['cancellation_policy'] = with_cat_df.drop(['cancellation_policy'], axis=1)

# %% [markdown]
# ### One Hot Encoding to property_type

# %%
with_cat_df = pd.get_dummies(with_cat_df, prefix=['property_type'], columns=['property_type'])

# %% [markdown]
# # Features Creation

# %% [markdown]
# - **listing_duration** = (last_review - first_review) - value to be evaluated in days
# - **hosting_duration** = (last_review - host_since) - value to be evaluated in days
# - **price_per_person** - (price/accommodates)

# %%
# listing_duration = (last_review - first_review) - value to be evaluated in days
with_cat_df['listing_duration'] = with_cat_df['first_review_days'] - with_cat_df['last_review_days']

# hosting_duration = (last_review - host_since) - value to be evaluated in days
with_cat_df['hosting_duration'] = with_cat_df['host_since_days'] - with_cat_df['last_review_days']

# price_per_person = (price/accommodates)
with_cat_df['price_per_person'] = (with_cat_df['price']/with_cat_df['accommodates'])

# %%
amenities_df = pd.DataFrame(columns = ['name'])
amenities_df['name'] = with_cat_df['amenities']

# %%
amenities_df['name'] = amenities_df['name'].parallel_apply(lambda x: x.strip('}{').split(','))
amenities_df['name'] = amenities_df['name'].parallel_apply(lambda x: [re.sub("['\"]","", l ) for l in x])

# %%
amenities_df.shape
# Out:
# (50796, 1)

# %%
import pandas
from sklearn.preprocessing import MultiLabelBinarizer

# Binarise labels
mlb = MultiLabelBinarizer()
expandedLabelData = mlb.fit_transform(amenities_df["name"])
labelClasses = mlb.classes_
expandedLabels = pandas.DataFrame(expandedLabelData, columns=labelClasses)

# %%
final_df = pd.concat([with_cat_df, expandedLabels], axis=1).drop(['amenities'], axis=1).reset_index()

# %%
final_df.sample(5)
# Out:
#        index host_response_time  host_response_rate  host_acceptance_rate  \
# 9928    9928                  0                 0.0                   0.0
# 50627  50627                  0                 0.0                   0.0
# 8758    8758                  0                 0.0                   0.0
# 28677  28677                 98                98.0                  99.0
# 16411  16411                  0                 0.0                   0.0
#
#        host_is_superhost  host_total_listings_count  host_has_profile_pic  \
# 9928                   0                        1.0                     1
# 50627                  0                        1.0                     1
# 8758                   0                        1.0                     1
# 28677                  0                       36.0                     1
# 16411                  0                        1.0                     1
#
#        host_identity_verified  is_location_exact  accommodates  bathrooms  \
# 9928                        1                  1             3        1.0
# 50627                       0                  1             4        1.0
# 8758                        1                  1             2        1.0
# 28677                       0                  1             1        2.0
# 16411                       1                  1             2        1.0
#
#        bedrooms  beds  price  security_deposit  cleaning_fee  guests_included  \
# 9928        0.0   2.0   97.0             200.0          30.0                1
# 50627       1.0   2.0  200.0               0.0          90.0                2
# 8758        1.0   1.0  150.0               0.0          50.0                1
# 28677       1.0   1.0   60.0               0.0          24.0                1
# 16411       1.0   1.0   55.0               0.0           0.0                1
#
#        extra_people  minimum_nights  maximum_nights has_availability  \
# 9928            0.0               5              15                t
# 50627          50.0               1            1125                t
# 8758            0.0               6              10                t
# 28677           0.0               2              20                t
# 16411           0.0               2            1125                t
#
#        number_of_reviews  number_of_reviews_ltm  review_scores_rating  \
# 9928                   2                      0                  90.0
# 50627                  0                      0                   0.0
# 8758                   0                      0                   0.0
# 28677                 38                     31                  90.0
# 16411                  1                      0                 100.0
#
#        review_scores_accuracy  review_scores_cleanliness  \
# 9928                 8.000000                   6.000000
# 50627                9.613552                   9.284211
# 8758                 9.613552                   9.284211
# 28677                9.000000                   9.000000
# 16411               10.000000                   8.000000
#
#        review_scores_checkin  review_scores_communication  \
# 9928                9.000000                     9.000000
# 50627               9.734848                     9.740066
# 8758                9.734848                     9.740066
# 28677              10.000000                    10.000000
# 16411              10.000000                    10.000000
#
#        review_scores_location  review_scores_value  requires_license  \
# 9928                 7.000000             7.000000                 0
# 50627                9.599812             9.386351                 0
# 8758                 9.599812             9.386351                 0
# 28677                9.000000             9.000000                 0
# 16411               10.000000            10.000000                 0
#
#        instant_bookable  is_business_travel_ready cancellation_policy  \
# 9928                  0                         0                   0
# 50627                 0                         0                   0
# 8758                  0                         0                   0
# 28677                 1                         0                  98
# 16411                 0                         0                   0
#
#        require_guest_profile_picture  require_guest_phone_verification  \
# 9928                               0                                 0
# 50627                              0                                 0
# 8758                               0                                 0
# 28677                              0                                 0
# 16411                              0                                 0
#
#        calculated_host_listings_count  \
# 9928                                1
# 50627                               1
# 8758                                1
# 28677                               5
# 16411                               1
#
#        calculated_host_listings_count_entire_homes  \
# 9928                                             1
# 50627                                            1
# 8758                                             1
# 28677                                            0
# 16411                                            0
#
#        calculated_host_listings_count_private_rooms  \
# 9928                                              0
# 50627                                             0
# 8758                                              0
# 28677                                             5
# 16411                                             1
#
#        calculated_host_listings_count_shared_rooms  reviews_per_month  \
# 9928                                             0           0.040000
# 50627                                            0           1.282087
# 8758                                             0           1.282087
# 28677                                            0           1.960000
# 16411                                            0           0.020000
#
#        first_review_days  last_review_days  host_since_days  \
# 9928              1655.0            1271.0           1964.0
# 50627                0.0               0.0             46.0
# 8758                 0.0               0.0           1992.0
# 28677              621.0              59.0           1144.0
# 16411             1352.0            1352.0           2082.0
#
#        calendar_last_scraped_days  host_response_time_ordinal  \
# 9928                           42                           1
# 50627                          42                           1
# 8758                           42                           1
# 28677                          42                           2
# 16411                          42                           1
#
#        bed_type_Airbed  bed_type_Couch  bed_type_Futon  \
# 9928                 0               0               0
# 50627                0               0               0
# 8758                 0               0               0
# 28677                0               0               0
# 16411                0               0               0
#
#        bed_type_Pull-out Sofa  bed_type_Real Bed  neighbourhood_group_Bronx  \
# 9928                        0                  1                          0
# 50627                       0                  1                          0
# 8758                        0                  1                          0
# 28677                       0                  1                          0
# 16411                       0                  1                          0
#
#        neighbourhood_group_Brooklyn  neighbourhood_group_Manhattan  \
# 9928                              1                              0
# 50627                             0                              1
# 8758                              1                              0
# 28677                             1                              0
# 16411                             1                              0
#
#        neighbourhood_group_Queens  neighbourhood_group_Staten Island  \
# 9928                            0                                  0
# 50627                           0                                  0
# 8758                            0                                  0
# 28677                           0                                  0
# 16411                           0                                  0
#
#        room_type_Entire home/apt  room_type_Hotel room  \
# 9928                           1                     0
# 50627                          1                     0
# 8758                           1                     0
# 28677                          0                     0
# 16411                          0                     0
#
#        room_type_Private room  room_type_Shared room  \
# 9928                        0                      0
# 50627                       0                      0
# 8758                        0                      0
# 28677                       1                      0
# 16411                       1                      0
#
#        cancellation_policy_ordinal  property_type_Aparthotel  \
# 9928                             1                         0
# 50627                            4                         0
# 8758                             4                         0
# 28677                            1                         0
# 16411                            1                         0
#
#        property_type_Apartment  property_type_Barn  \
# 9928                         1                   0
# 50627                        1                   0
# 8758                         1                   0
# 28677                        1                   0
# 16411                        1                   0
#
#        property_type_Bed and breakfast  property_type_Boat  \
# 9928                                 0                   0
# 50627                                0                   0
# 8758                                 0                   0
# 28677                                0                   0
# 16411                                0                   0
#
#        property_type_Boutique hotel  property_type_Bungalow  \
# 9928                              0                       0
# 50627                             0                       0
# 8758                              0                       0
# 28677                             0                       0
# 16411                             0                       0
#
#        property_type_Bus  property_type_Cabin  property_type_Camper/RV  \
# 9928                   0                    0                        0
# 50627                  0                    0                        0
# 8758                   0                    0                        0
# 28677                  0                    0                        0
# 16411                  0                    0                        0
#
#        property_type_Casa particular (Cuba)  property_type_Castle  \
# 9928                                      0                     0
# 50627                                     0                     0
# 8758                                      0                     0
# 28677                                     0                     0
# 16411                                     0                     0
#
#        property_type_Cave  property_type_Condominium  property_type_Cottage  \
# 9928                    0                          0                      0
# 50627                   0                          0                      0
# 8758                    0                          0                      0
# 28677                   0                          0                      0
# 16411                   0                          0                      0
#
#        property_type_Dome house  property_type_Dorm  \
# 9928                          0                   0
# 50627                         0                   0
# 8758                          0                   0
# 28677                         0                   0
# 16411                         0                   0
#
#        property_type_Earth house  property_type_Farm stay  \
# 9928                           0                        0
# 50627                          0                        0
# 8758                           0                        0
# 28677                          0                        0
# 16411                          0                        0
#
#        property_type_Guest suite  property_type_Guesthouse  \
# 9928                           0                         0
# 50627                          0                         0
# 8758                           0                         0
# 28677                          0                         0
# 16411                          0                         0
#
#        property_type_Hostel  property_type_Hotel  property_type_House  \
# 9928                      0                    0                    0
# 50627                     0                    0                    0
# 8758                      0                    0                    0
# 28677                     0                    0                    0
# 16411                     0                    0                    0
#
#        property_type_Houseboat  property_type_In-law  property_type_Island  \
# 9928                         0                     0                     0
# 50627                        0                     0                     0
# 8758                         0                     0                     0
# 28677                        0                     0                     0
# 16411                        0                     0                     0
#
#        property_type_Lighthouse  property_type_Loft  property_type_Other  \
# 9928                          0                   0                    0
# 50627                         0                   0                    0
# 8758                          0                   0                    0
# 28677                         0                   0                    0
# 16411                         0                   0                    0
#
#        property_type_Resort  property_type_Serviced apartment  \
# 9928                      0                                 0
# 50627                     0                                 0
# 8758                      0                                 0
# 28677                     0                                 0
# 16411                     0                                 0
#
#        property_type_Tent  property_type_Timeshare  property_type_Tiny house  \
# 9928                    0                        0                         0
# 50627                   0                        0                         0
# 8758                    0                        0                         0
# 28677                   0                        0                         0
# 16411                   0                        0                         0
#
#        property_type_Townhouse  property_type_Train  property_type_Treehouse  \
# 9928                         0                    0                        0
# 50627                        0                    0                        0
# 8758                         0                    0                        0
# 28677                        0                    0                        0
# 16411                        0                    0                        0
#
#        property_type_Villa  property_type_Yurt  listing_duration  \
# 9928                     0                   0             384.0
# 50627                    0                   0               0.0
# 8758                     0                   0               0.0
# 28677                    0                   0             562.0
# 16411                    0                   0               0.0
#
#        hosting_duration  price_per_person      toilet  24-hour check-in  \
# 9928              693.0         32.333333  0        0                 0
# 50627              46.0         50.000000  0        0                 0
# 8758             1992.0         75.000000  0        0                 0
# 28677            1085.0         60.000000  0        0                 0
# 16411             730.0         27.500000  0        0                 0
#
#        Accessible-height bed  Accessible-height toilet  Air conditioning  \
# 9928                       0                         0                 1
# 50627                      0                         0                 1
# 8758                       0                         0                 1
# 28677                      0                         0                 1
# 16411                      0                         0                 0
#
#        Air purifier  BBQ grill  Baby bath  Baby monitor  \
# 9928              0          0          0             0
# 50627             0          0          0             0
# 8758              0          0          0             0
# 28677             0          0          0             0
# 16411             0          0          0             0
#
#        Babysitter recommendations  Baking sheet  Barbecue utensils  \
# 9928                            0             0                  0
# 50627                           0             0                  0
# 8758                            0             0                  0
# 28677                           0             0                  0
# 16411                           0             0                  0
#
#        Bath towel  Bathrobes  Bathroom essentials  Bathtub  \
# 9928            0          0                    0        0
# 50627           0          0                    0        1
# 8758            0          0                    0        0
# 28677           0          0                    0        0
# 16411           0          0                    0        0
#
#        Bathtub with bath chair  Beach essentials  Beachfront  Bed linens  \
# 9928                         0                 0           0           0
# 50627                        0                 0           0           1
# 8758                         0                 0           0           0
# 28677                        0                 0           0           1
# 16411                        0                 0           0           0
#
#        Bedroom comforts  Bluetooth speaker  Body soap  Bottled water  \
# 9928                  0                  0          0              0
# 50627                 0                  0          0              0
# 8758                  0                  0          0              0
# 28677                 0                  0          0              0
# 16411                 0                  0          0              0
#
#        Bread maker  Breakfast  Building staff  Buzzer/wireless intercom  \
# 9928             0          0               0                         1
# 50627            0          0               0                         0
# 8758             0          0               0                         1
# 28677            0          0               0                         0
# 16411            0          0               0                         0
#
#        Cable TV  Carbon monoxide detector  Cat(s)  Changing table  \
# 9928          1                         1       0               0
# 50627         0                         1       0               0
# 8758          1                         1       0               0
# 28677         0                         1       0               0
# 16411         0                         0       0               0
#
#        Children’s books and toys  Children’s dinnerware  \
# 9928                           0                      0
# 50627                          0                      0
# 8758                           0                      0
# 28677                          0                      0
# 16411                          0                      0
#
#        Cleaning before checkout  Coffee maker  Cooking basics  Crib  \
# 9928                          0             0               0     0
# 50627                         1             1               1     0
# 8758                          0             0               0     0
# 28677                         0             1               1     0
# 16411                         0             0               0     0
#
#        Disabled parking spot  Dishes and silverware  Dishwasher  Dog(s)  \
# 9928                       0                      0           0       0
# 50627                      0                      1           1       0
# 8758                       0                      0           0       0
# 28677                      0                      1           0       0
# 16411                      0                      0           0       0
#
#        Doorman  Dryer  EV charger  Electric profiling bed  Elevator  \
# 9928         0      1           0                       0         1
# 50627        0      0           0                       0         0
# 8758         0      0           0                       0         0
# 28677        0      0           0                       0         0
# 16411        0      0           0                       0         0
#
#        Essentials  Ethernet connection  Extra pillows and blankets  \
# 9928            1                    0                           0
# 50627           1                    0                           1
# 8758            1                    0                           0
# 28677           1                    0                           1
# 16411           1                    0                           0
#
#        Extra space around bed  Family/kid friendly  Fire extinguisher  \
# 9928                        0                    0                  0
# 50627                       0                    0                  0
# 8758                        0                    0                  0
# 28677                       0                    0                  1
# 16411                       0                    0                  0
#
#        Fireplace guards  Firm mattress  First aid kit  \
# 9928                  0              0              0
# 50627                 0              0              0
# 8758                  0              0              0
# 28677                 0              0              1
# 16411                 0              0              0
#
#        Fixed grab bars for shower  Fixed grab bars for toilet  \
# 9928                            0                           0
# 50627                           0                           0
# 8758                            0                           0
# 28677                           0                           0
# 16411                           0                           0
#
#        Flat path to guest entrance  Free parking on premises  \
# 9928                             0                         0
# 50627                            0                         0
# 8758                             0                         0
# 28677                            0                         0
# 16411                            0                         0
#
#        Free street parking  Full kitchen  Game console  Garden or backyard  \
# 9928                     0             0             0                   0
# 50627                    1             0             0                   0
# 8758                     0             0             0                   0
# 28677                    1             0             0                   0
# 16411                    0             0             0                   0
#
#        Ground floor access  Gym  Hair dryer  Handheld shower head  Hangers  \
# 9928                     0    1           0                     0        0
# 50627                    0    0           1                     0        1
# 8758                     0    0           0                     0        0
# 28677                    0    0           1                     0        1
# 16411                    0    0           0                     0        0
#
#        Heating  High chair  Host greets you  Hot tub  Hot water  \
# 9928         1           0                0        0          0
# 50627        1           0                0        0          1
# 8758         1           0                0        0          0
# 28677        1           0                0        0          1
# 16411        1           0                0        0          0
#
#        Hot water kettle  Indoor fireplace  Internet  Iron  Keypad  Kitchen  \
# 9928                  0                 0         1     0       0        1
# 50627                 0                 0         0     1       0        1
# 8758                  0                 0         1     0       0        1
# 28677                 0                 0         0     1       0        1
# 16411                 0                 0         0     0       0        1
#
#        Kitchenette  Lake access  Laptop friendly workspace  \
# 9928             0            0                          0
# 50627            0            0                          1
# 8758             0            0                          0
# 28677            0            0                          1
# 16411            0            0                          1
#
#        Lock on bedroom door  Lockbox  Long term stays allowed  \
# 9928                      0        0                        0
# 50627                     0        0                        1
# 8758                      0        0                        0
# 28677                     1        0                        0
# 16411                     1        0                        0
#
#        Luggage dropoff allowed  Microwave  Mini bar  Mini fridge  \
# 9928                         0          0         0            0
# 50627                        1          0         0            0
# 8758                         0          0         0            0
# 28677                        0          1         0            0
# 16411                        0          0         0            0
#
#        Mobile hoist  No stairs or steps to enter  Other  Other pet(s)  \
# 9928              0                            0      0             0
# 50627             0                            0      0             0
# 8758              0                            0      0             0
# 28677             0                            0      1             0
# 16411             0                            0      0             0
#
#        Outlet covers  Oven  Pack ’n Play/travel crib  \
# 9928               0     0                         0
# 50627              0     1                         0
# 8758               0     0                         0
# 28677              0     1                         0
# 16411              0     0                         0
#
#        Paid parking off premises  Paid parking on premises  Patio or balcony  \
# 9928                           0                         0                 0
# 50627                          1                         0                 0
# 8758                           0                         0                 0
# 28677                          1                         0                 0
# 16411                          0                         0                 0
#
#        Pets allowed  Pets live on this property  Pocket wifi  Pool  \
# 9928              0                           0            0     0
# 50627             0                           0            0     0
# 8758              0                           0            0     0
# 28677             0                           0            0     0
# 16411             0                           0            0     0
#
#        Private bathroom  Private entrance  Private living room  Record player  \
# 9928                  0                 0                    0              0
# 50627                 0                 1                    0              0
# 8758                  0                 0                    0              0
# 28677                 0                 0                    0              0
# 16411                 0                 0                    0              0
#
#        Refrigerator  Room-darkening shades  Safe  Safety card  Self check-in  \
# 9928              0                      0     0            0              0
# 50627             1                      1     0            0              0
# 8758              0                      0     0            0              0
# 28677             1                      0     0            0              0
# 16411             0                      0     0            0              0
#
#        Shampoo  Shower chair  Shower gel  Single level home  Ski-in/Ski-out  \
# 9928         1             0           0                  0               0
# 50627        1             0           1                  0               0
# 8758         1             0           0                  0               0
# 28677        0             0           0                  0               0
# 16411        0             0           0                  0               0
#
#        Slippers  Smart lock  Smoke detector  Smoking allowed  Snacks  \
# 9928          0           0               1                0       0
# 50627         0           0               1                0       0
# 8758          0           0               1                0       0
# 28677         0           0               1                0       0
# 16411         0           0               1                0       0
#
#        Stair gates  Step-free shower  Stove  Suitable for events  TV  \
# 9928             0                 0      0                    0   1
# 50627            0                 0      1                    0   1
# 8758             0                 0      0                    0   1
# 28677            0                 0      1                    0   0
# 16411            0                 0      0                    0   0
#
#        Table corner guards  Toilet paper  Trash can  Turndown service  Washer  \
# 9928                     0             0          0                 0       1
# 50627                    0             0          1                 0       0
# 8758                     0             0          0                 0       0
# 28677                    0             0          0                 0       0
# 16411                    0             0          0                 0       0
#
#        Washer/Dryer  Waterfront  Well-lit path to entrance  \
# 9928              0           0                          0
# 50627             0           0                          0
# 8758              0           0                          0
# 28677             0           0                          0
# 16411             0           0                          0
#
#        Wheelchair accessible  Wide clearance to shower  \
# 9928                       0                         0
# 50627                      0                         0
# 8758                       0                         0
# 28677                      0                         0
# 16411                      0                         0
#
#        Wide doorway to guest bathroom  Wide entrance  \
# 9928                                0              0
# 50627                               0              0
# 8758                                0              0
# 28677                               0              0
# 16411                               0              0
#
#        Wide entrance for guests  Wide entryway  Wide hallways  Wifi  \
# 9928                          0              0              0     1
# 50627                         0              0              0     1
# 8758                          0              0              0     1
# 28677                         0              0              0     1
# 16411                         0              0              0     0
#
#        Window guards  translation missing: en.hosting_amenity_49  \
# 9928               0                                           0
# 50627              0                                           0
# 8758               0                                           0
# 28677              0                                           0
# 16411              0                                           1
#
#        translation missing: en.hosting_amenity_50
# 9928                                            0
# 50627                                           0
# 8758                                            0
# 28677                                           0
# 16411                                           1

# %%
final_df.to_csv('data/final-features.csv', sep=';', index=False)

# %% [markdown]
# ### It's expensive to travel in the weekends ?
# ### Which price average in most hosted neighborhood?
